# %% [markdown]
# # Call Center Simulation

# %% [markdown]
# ## Authors
# * Dilara Gökay (2014400102)
# * Hatice Kübra Eryılmaz (2014400186)
# * Recep Deniz Aksoy (2014400150)

# %% [markdown]
# ## Description
# This assignment shows how a call center can be modeled with a process-interaction view using the [SimPy](https://simpy.readthedocs.io/en/latest/) library.
#
# There are two operators in the system, one is **unskilled** and the other is **expert**. Incoming customers first wait for unskilled operator in a FCFS queue. When they are finished with unskilled operator they wait for expert operator in a FCFS queue. When they are finished with expert operator they leave the system.
#
# In addition to the general flow of the system, expert operator takes break during his/her shift. When the operator decides to take a break, he/she waits until completing all the customers already waiting for her/him. If a new customer arrives after the operator decides to take a break, the operator serves that customer after the break.
#
# The customers are assumed to be extremely patient, as they wait as long as it gets to talk to the operator.
#
# Properties of the system are following:
#
# * In this system, the durations between two consecutive calls are observed to be exponentially distributed with a mean of 15,6 minutes.
# * The time it takes unskilled operator to collect and record the details of a caller is assumed to be distributed according to the Gaussian (i.e. Normal) distribution with a mean of 4,2 and a standard deviation of 1,5 minutes.
# * The service time of the expert operator is Exponentially distributed with a mean of 9,3 minutes.
# * The expert operator takes 5-min breaks randomly through out the day.
# * The number of breaks the expert operator wishes to take during an 8-hour shift is known to be distributed according to a Poisson distribution with a mean of 8 breaks per shift.

# %% [markdown]
# ## Deliverables
# * Following results are printed in the end of the document.
#    * server utilization
#    * average total waiting time
#    * maximum total waiting time to total system time ratio
#    * average number of people waiting to be served by the expert operator
# * The current number of customers is 1000. This can be changed to 5000 or another number by changing the global variable `NUMBER_OF_CUSTOMERS`
# * Current expert service times are distributed exponentially. Please change global variable `EXPERT_DISTRIBUTION` from `exp` to `normal` for  $ServiceTime \sim N(9.3, (3.1)^2)$

# %% [markdown]
# ## Simulation

# %%
import simpy  # for simulation
import random  # for distributions
import numpy as np  # for Poisson distribution

# %% [markdown]
# Define a set of globals that define the characteristics of the model instance to be simulated. This includes the seed (RANDOM_SEED) for the random number generators, and key parameters for the interarrival (i.e. mean arrival rate) and service time (i.e. lower and upper bounds for the range) distribution.

# %%
RANDOM_SEED = 9780 # for the random number generators
INTERARRIVAL_RATE = 15.6 
NUMBER_OF_CUSTOMERS = 1000
random.seed(RANDOM_SEED)
last_cust_flag = True # used for managing number of breaks
EXPERT_DISTRIBUTION = 'exp'

# %% [markdown]
# Define the necessary set of variables for bookkeeping

# %%
service_times = []  # duration of the conversation between the customer and the operator (Service time)
queue_w_times = []  # time spent by a customer while it waits for the operator (Queue waiting time Wq)
working_time_unskilled = 0  # total amount of time in which the expert operator is busy
working_time_expert = 0  # total amount of time in which the expert operator is busy
total_waiting_time = [0]  # total waiting time for both operators
total_waiting_time_expert = [0]  # total waiting time for expert operator
max_waiting_time = [0]  # max waiting time for both operators
max_time = 0

# %% [markdown]
# * Class for the customers arriving at system. When they are created, they immediatelly initiate a call to unskilled operator (i.e. activate the call process).
# * Once a call is initiated, this is registered as a request to the unskilled operator resource. The customer is put on hold until the resource activates it back.
# * Once the customer is finished with unskilled operator it requests (and waits, if necessary) the expert operator.

# %%
class Customer(object):
    global total_waiting_time, max_waiting_time, last_cust_flag, total_waiting_time_expert, max_time
    def __init__(self, name, env, opr):
        self.env = env
        self.name = name
        self.arrival_t = self.env.now
        self.action = env.process(self.call())
    
    
    def call(self):
        global last_cust_flag, max_time
        print('%s initiated a call at %g' % (self.name, self.env.now))
        un_wait = self.env.now
        arrival_expert = 1000000 # the time in which customer is finished with unskilled and starts to wait for expert
        with unskilled_operator.request() as req:
            yield req
            print('%s is assigned to an unskilled_operator at %g' % (self.name, self.env.now))
            un_wait = self.env.now - un_wait
            queue_w_times.append(self.env.now - self.arrival_t)
            total_waiting_time[0]+= self.env.now - self.arrival_t
            yield self.env.process(self.ask_question())
            print('%s is done at unskilled operator on %g' % (self.name, self.env.now))
            exp_wait = self.env.now
            arrival_expert = self.env.now
        with expert_operator.request(priority = 1) as req:
            yield req
            total_waiting_time[0]+= self.env.now - arrival_expert
            total_waiting_time_expert[0]+=self.env.now - arrival_expert
            if self.env.now - self.arrival_t > max_waiting_time[0]:
                max_waiting_time[0] = self.env.now - self.arrival_t
            exp_wait = self.env.now - exp_wait
            print('%s is assigned to an expert operator at %g' % (self.name, self.env.now))
            yield self.env.process(self.ask_question_expert())
            print('%s is done at expert operator on %g' % (self.name, self.env.now))
            wait_total_ratio = (un_wait + exp_wait) / (self.env.now - self.arrival_t)
            if(wait_total_ratio > max_time):
                max_time = wait_total_ratio
            if(self.name[5:] == str((NUMBER_OF_CUSTOMERS - 1))):
                last_cust_flag = False
                
    def ask_question(self):
        global working_time_unskilled
        duration = abs(random.normalvariate(4.2, 1.5))
        print("duration is %s" %duration)
        yield self.env.timeout(duration)
        working_time_unskilled+=duration
        service_times.append(duration)

    def ask_question_expert(self):
        global working_time_expert
        if EXPERT_DISTRIBUTION == 'exp':
            duration = abs(random.expovariate(1/9.3))
        else:
            duration = abs(random.normalvariate(9.3, 3.1))
        yield self.env.timeout(duration)
        working_time_expert+=duration

# %% [markdown]
# Break is just like a customer which has the lowest priority among all customers and constant service time(5 min).

# %%
class Break(object):
    def __init__(self, name, env, opr):
        self.env = env
        self.name = name
        self.arrival_t = self.env.now
        self.action = env.process(self.call())
        
    def call(self):
        print('A break is initiated at %g' % (self.env.now))
        
        with expert_operator.request(priority = 1000000) as req:
            yield req
            yield self.env.process(self.give_break())
            print('A break is finished at %g' % (self.env.now))
                    
    def give_break(self):
        yield self.env.timeout(5)

# %%
def customer_generator(env, operator):
    global end, last_cust_flag
    for i in range(NUMBER_OF_CUSTOMERS):
        yield env.timeout(abs(random.expovariate(1/INTERARRIVAL_RATE)))
        customer = Customer('Cust %s' %(i+1), env, unskilled_operator)

# %%
def break_generator(env, operator):
    while(last_cust_flag):
        x = np.random.poisson(1/60.0)
        if(x > 0):
            break_ = Break('Break' , env, operator)
        yield env.timeout(1)

# %%
env = simpy.Environment()
unskilled_operator = simpy.Resource(env, capacity = 1)
expert_operator = simpy.PriorityResource(env, capacity = 1)
env.process(customer_generator(env, unskilled_operator))
env.process(break_generator(env, expert_operator))
env.run()
total_time = env.now
# Out:
# Cust 1 initiated a call at 8.61921
# Cust 1 is assigned to an unskilled_operator at 8.61921
# duration is 6.217751562636504
# Cust 2 initiated a call at 13.1948
# Cust 1 is done at unskilled operator on 14.837
# Cust 1 is assigned to an expert operator at 14.837
# Cust 2 is assigned to an unskilled_operator at 14.837
# duration is 2.4806954891501443
# Cust 2 is done at unskilled operator on 17.3177
# Cust 1 is done at expert operator on 18.6759
# Cust 2 is assigned to an expert operator at 18.6759
# Cust 2 is done at expert operator on 26.0204
# Cust 3 initiated a call at 27.4642
# Cust 3 is assigned to an unskilled_operator at 27.4642
# duration is 3.7400509391032157
# Cust 3 is done at unskilled operator on 31.2042
# Cust 3 is assigned to an expert operator at 31.2042
# Cust 3 is done at expert operator on 44.2056
# A break is initiated at 56
# A break is finished at 61
# A break is initiated at 62
# A break is initiated at 65
# A break is finished at 67
# A break is finished at 72
# Cust 4 initiated a call at 93.9065
# Cust 4 is assigned to an unskilled_operator at 93.9065
# duration is 6.8345714017941654
# Cust 5 initiated a call at 95.4494
# Cust 4 is done at unskilled operator on 100.741
# Cust 4 is assigned to an expert operator at 100.741
# Cust 5 is assigned to an unskilled_operator at 100.741
# duration is 3.424924398716875
# Cust 5 is done at unskilled operator on 104.166
# Cust 4 is done at expert operator on 106.347
# Cust 5 is assigned to an expert operator at 106.347
# Cust 6 initiated a call at 113.669
# Cust 6 is assigned to an unskilled_operator at 113.669
# duration is 4.987338594349847
# Cust 7 initiated a call at 117.959
# Cust 6 is done at unskilled operator on 118.656
# Cust 7 is assigned to an unskilled_operator at 118.656
# duration is 5.593599499327114
# A break is initiated at 122
# Cust 7 is done at unskilled operator on 124.249
# Cust 5 is done at expert operator on 126.996
# Cust 6 is assigned to an expert operator at 126.996
# Cust 6 is done at expert operator on 137.492
# Cust 7 is assigned to an expert operator at 137.492
# Cust 7 is done at expert operator on 138.035
# A break is finished at 143.035
# A break is initiated at 159
# A break is finished at 164
# Cust 8 initiated a call at 198.655
# Cust 8 is assigned to an unskilled_operator at 198.655
# duration is 6.135051628310844
# Cust 8 is done at unskilled operator on 204.79
# Cust 8 is assigned to an expert operator at 204.79
# Cust 8 is done at expert operator on 213.104
# Cust 9 initiated a call at 225.968
# Cust 9 is assigned to an unskilled_operator at 225.968
# duration is 4.330541540666791
# Cust 9 is done at unskilled operator on 230.298
# Cust 9 is assigned to an expert operator at 230.298
# Cust 9 is done at expert operator on 248.632
# Cust 10 initiated a call at 267.122
# Cust 10 is assigned to an unskilled_operator at 267.122
# duration is 4.750846595416436
# Cust 10 is done at unskilled operator on 271.873
# Cust 10 is assigned to an expert operator at 271.873
# Cust 11 initiated a call at 274.686
# Cust 11 is assigned to an unskilled_operator at 274.686
# duration is 5.248824114608
# A break is initiated at 278
# Cust 11 is done at unskilled operator on 279.934
# Cust 10 is done at expert operator on 302.9
# Cust 11 is assigned to an expert operator at 302.9
# Cust 12 initiated a call at 304.139
# Cust 12 is assigned to an unskilled_operator at 304.139
# duration is 3.473296527194569
# Cust 11 is done at expert operator on 304.893
# Cust 13 initiated a call at 305.506
# Cust 12 is done at unskilled operator on 307.612
# Cust 13 is assigned to an unskilled_operator at 307.612
# duration is 4.062375202069205
# A break is finished at 309.893
# Cust 12 is assigned to an expert operator at 309.893
# Cust 13 is done at unskilled operator on 311.674
# Cust 12 is done at expert operator on 322.45
# Cust 13 is assigned to an expert operator at 322.45
# Cust 13 is done at expert operator on 323.111
# A break is initiated at 324
# A break is finished at 329
# Cust 14 initiated a call at 349.947
# Cust 14 is assigned to an unskilled_operator at 349.947
# duration is 1.3443117325494902
# Cust 14 is done at unskilled operator on 351.291
# Cust 14 is assigned to an expert operator at 351.291
# Cust 15 initiated a call at 351.66
# Cust 15 is assigned to an unskilled_operator at 351.66
# duration is 6.3767597331711725
# Cust 16 initiated a call at 355.991
# Cust 15 is done at unskilled operator on 358.037
# Cust 16 is assigned to an unskilled_operator at 358.037
# duration is 2.2884717361444964
# Cust 16 is done at unskilled operator on 360.326
# Cust 17 initiated a call at 366.095
# Cust 17 is assigned to an unskilled_operator at 366.095
# duration is 6.318037616878184
# Cust 18 initiated a call at 371.701
# Cust 17 is done at unskilled operator on 372.413
# Cust 18 is assigned to an unskilled_operator at 372.413
# duration is 5.30831503131372
# Cust 19 initiated a call at 373.759
# Cust 18 is done at unskilled operator on 377.721
# Cust 19 is assigned to an unskilled_operator at 377.721
# duration is 5.741406939564295
# Cust 14 is done at expert operator on 382.273
# Cust 15 is assigned to an expert operator at 382.273
# Cust 19 is done at unskilled operator on 383.463
# Cust 15 is done at expert operator on 383.693
# Cust 16 is assigned to an expert operator at 383.693
# Cust 20 initiated a call at 395.761
# Cust 20 is assigned to an unskilled_operator at 395.761
# duration is 6.094091530317352
# A break is initiated at 401
# Cust 20 is done at unskilled operator on 401.855
# Cust 21 initiated a call at 410.186
# Cust 21 is assigned to an unskilled_operator at 410.186
# duration is 5.793057961796679
# Cust 21 is done at unskilled operator on 415.98
# Cust 16 is done at expert operator on 420.648
# Cust 17 is assigned to an expert operator at 420.648
# Cust 17 is done at expert operator on 426.613
# Cust 18 is assigned to an expert operator at 426.613
# Cust 18 is done at expert operator on 433.038
# Cust 19 is assigned to an expert operator at 433.038
# Cust 22 initiated a call at 469.653
# Cust 22 is assigned to an unskilled_operator at 469.653
# duration is 3.90886308984476
# Cust 22 is done at unskilled operator on 473.562
# Cust 19 is done at expert operator on 482.634
# Cust 20 is assigned to an expert operator at 482.634
# Cust 23 initiated a call at 489.041
# Cust 23 is assigned to an unskilled_operator at 489.041
# duration is 5.5057554099882235
# Cust 24 initiated a call at 490.027
# Cust 23 is done at unskilled operator on 494.547
# Cust 24 is assigned to an unskilled_operator at 494.547
# duration is 5.032590770653245
# Cust 24 is done at unskilled operator on 499.58
# A break is initiated at 506
# Cust 20 is done at expert operator on 510.218
# Cust 21 is assigned to an expert operator at 510.218
# Cust 25 initiated a call at 510.422
# Cust 25 is assigned to an unskilled_operator at 510.422
# duration is 3.4929519304974534
# Cust 21 is done at expert operator on 511.896
# Cust 22 is assigned to an expert operator at 511.896
# Cust 26 initiated a call at 513.122
# Cust 25 is done at unskilled operator on 513.915
# Cust 26 is assigned to an unskilled_operator at 513.915
# duration is 1.9723445161581186
# Cust 26 is done at unskilled operator on 515.887
# Cust 27 initiated a call at 521.897
# Cust 27 is assigned to an unskilled_operator at 521.897
# duration is 5.431693789920352
# Cust 27 is done at unskilled operator on 527.329
# Cust 28 initiated a call at 532.73
# Cust 28 is assigned to an unskilled_operator at 532.73
# duration is 4.363904261086041
# Cust 29 initiated a call at 534.034
# Cust 22 is done at expert operator on 534.519
# Cust 23 is assigned to an expert operator at 534.519
# Cust 30 initiated a call at 536.74
# Cust 28 is done at unskilled operator on 537.094
# Cust 29 is assigned to an unskilled_operator at 537.094
# duration is 3.835433927687174
# Cust 31 initiated a call at 539.261
# Cust 29 is done at unskilled operator on 540.93
# Cust 30 is assigned to an unskilled_operator at 540.93
# duration is 4.176708122508111
# Cust 30 is done at unskilled operator on 545.106
# Cust 31 is assigned to an unskilled_operator at 545.106
# duration is 6.2239011574607455
# Cust 32 initiated a call at 550.264
# Cust 31 is done at unskilled operator on 551.33
# Cust 32 is assigned to an unskilled_operator at 551.33
# duration is 4.1085539360177386
# A break is initiated at 552
# Cust 32 is done at unskilled operator on 555.439
# Cust 33 initiated a call at 565.654
# Cust 33 is assigned to an unskilled_operator at 565.654
# duration is 2.943699554029677
# Cust 33 is done at unskilled operator on 568.598
# Cust 23 is done at expert operator on 579.258
# Cust 24 is assigned to an expert operator at 579.258
# Cust 24 is done at expert operator on 594.06
# Cust 25 is assigned to an expert operator at 594.06
# Cust 25 is done at expert operator on 596.428
# Cust 26 is assigned to an expert operator at 596.428
# Cust 26 is done at expert operator on 601.947
# Cust 27 is assigned to an expert operator at 601.947
# Cust 34 initiated a call at 602.928
# Cust 34 is assigned to an unskilled_operator at 602.928
# duration is 5.464584005663218
# Cust 35 initiated a call at 604.8
# Cust 27 is done at expert operator on 605.143
# Cust 28 is assigned to an expert operator at 605.143
# Cust 36 initiated a call at 606.872
# Cust 34 is done at unskilled operator on 608.393
# Cust 35 is assigned to an unskilled_operator at 608.393
# duration is 4.471266205133741
# Cust 35 is done at unskilled operator on 612.864
# Cust 36 is assigned to an unskilled_operator at 612.864
# duration is 4.166078655675259
# Cust 37 initiated a call at 615.142
# Cust 28 is done at expert operator on 616.191
# Cust 29 is assigned to an expert operator at 616.191
# Cust 36 is done at unskilled operator on 617.03
# Cust 37 is assigned to an unskilled_operator at 617.03
# duration is 5.03547650463067
# Cust 37 is done at unskilled operator on 622.066
# A break is initiated at 627
# Cust 38 initiated a call at 627.175
# Cust 38 is assigned to an unskilled_operator at 627.175
# duration is 7.074649959922855
# Cust 38 is done at unskilled operator on 634.249
# Cust 39 initiated a call at 634.322
# Cust 39 is assigned to an unskilled_operator at 634.322
# duration is 6.4965275420143245
# Cust 39 is done at unskilled operator on 640.818
# Cust 40 initiated a call at 643.15
# Cust 40 is assigned to an unskilled_operator at 643.15
# duration is 3.605698648032778
# A break is initiated at 646
# Cust 40 is done at unskilled operator on 646.756
# Cust 29 is done at expert operator on 647.339
# Cust 30 is assigned to an expert operator at 647.339
# Cust 41 initiated a call at 654.42
# Cust 41 is assigned to an unskilled_operator at 654.42
# duration is 3.4809493603670405
# A break is initiated at 657
# Cust 42 initiated a call at 657.763
# Cust 41 is done at unskilled operator on 657.901
# Cust 42 is assigned to an unskilled_operator at 657.901
# duration is 3.904318566842606
# Cust 30 is done at expert operator on 659.819
# Cust 31 is assigned to an expert operator at 659.819
# Cust 42 is done at unskilled operator on 661.805
# A break is initiated at 662
# Cust 31 is done at expert operator on 662.871
# Cust 32 is assigned to an expert operator at 662.871
# Cust 32 is done at expert operator on 665.077
# Cust 33 is assigned to an expert operator at 665.077
# Cust 33 is done at expert operator on 674.984
# Cust 34 is assigned to an expert operator at 674.984
# Cust 34 is done at expert operator on 687.58
# Cust 35 is assigned to an expert operator at 687.58
# A break is initiated at 688
# Cust 35 is done at expert operator on 691.668
# Cust 36 is assigned to an expert operator at 691.668
# Cust 36 is done at expert operator on 692.311
# Cust 37 is assigned to an expert operator at 692.311
# Cust 37 is done at expert operator on 696.33
# Cust 38 is assigned to an expert operator at 696.33
# Cust 38 is done at expert operator on 706.927
# Cust 39 is assigned to an expert operator at 706.927
# Cust 39 is done at expert operator on 712.191
# Cust 40 is assigned to an expert operator at 712.191
# Cust 43 initiated a call at 721.466
# Cust 43 is assigned to an unskilled_operator at 721.466
# duration is 3.2925395357295075
# Cust 44 initiated a call at 722.465
# Cust 40 is done at expert operator on 723.221
# Cust 41 is assigned to an expert operator at 723.221
# Cust 43 is done at unskilled operator on 724.758
# Cust 44 is assigned to an unskilled_operator at 724.758
# duration is 3.7342219212629217
# Cust 45 initiated a call at 728.471
# Cust 44 is done at unskilled operator on 728.492
# Cust 45 is assigned to an unskilled_operator at 728.492
# duration is 5.599876015684925
# Cust 45 is done at unskilled operator on 734.092
# Cust 41 is done at expert operator on 735.914
# Cust 42 is assigned to an expert operator at 735.914
# Cust 46 initiated a call at 738.783
# Cust 46 is assigned to an unskilled_operator at 738.783
# duration is 2.8168518643824387
# Cust 42 is done at expert operator on 739.139
# Cust 43 is assigned to an expert operator at 739.139
# Cust 46 is done at unskilled operator on 741.599
# Cust 47 initiated a call at 749.958
# Cust 47 is assigned to an unskilled_operator at 749.958
# duration is 6.339033022852655
# Cust 47 is done at unskilled operator on 756.297
# Cust 43 is done at expert operator on 765.499
# Cust 44 is assigned to an expert operator at 765.499
# Cust 44 is done at expert operator on 767.567
# Cust 45 is assigned to an expert operator at 767.567
# Cust 48 initiated a call at 769.971
# Cust 48 is assigned to an unskilled_operator at 769.971
# duration is 4.647451288272616
# Cust 48 is done at unskilled operator on 774.618
# Cust 45 is done at expert operator on 787.597
# Cust 46 is assigned to an expert operator at 787.597
# Cust 46 is done at expert operator on 800.46
# Cust 47 is assigned to an expert operator at 800.46
# Cust 47 is done at expert operator on 811.567
# Cust 48 is assigned to an expert operator at 811.567
# Cust 48 is done at expert operator on 816.89
# Cust 49 initiated a call at 819.534
# Cust 49 is assigned to an unskilled_operator at 819.534
# duration is 1.977600544566009
# Cust 49 is done at unskilled operator on 821.512
# A break is finished at 821.89
# Cust 49 is assigned to an expert operator at 821.89
# Cust 50 initiated a call at 840.94
# Cust 50 is assigned to an unskilled_operator at 840.94
# duration is 4.78605851214675
# Cust 51 initiated a call at 845.335
# Cust 50 is done at unskilled operator on 845.726
# Cust 51 is assigned to an unskilled_operator at 845.726
# duration is 4.709207161956146
# Cust 51 is done at unskilled operator on 850.435
# Cust 49 is done at expert operator on 858.282
# Cust 50 is assigned to an expert operator at 858.282
# Cust 50 is done at expert operator on 859.837
# Cust 51 is assigned to an expert operator at 859.837
# Cust 51 is done at expert operator on 861.738
# A break is finished at 866.738
# Cust 52 initiated a call at 869.24
# Cust 52 is assigned to an unskilled_operator at 869.24
# duration is 1.6070052036700497
# Cust 52 is done at unskilled operator on 870.847
# A break is finished at 871.738
# Cust 52 is assigned to an expert operator at 871.738
# Cust 52 is done at expert operator on 879.895
# Cust 53 initiated a call at 882.839
# Cust 53 is assigned to an unskilled_operator at 882.839
# duration is 5.489734540790805
# A break is finished at 884.895
# Cust 53 is done at unskilled operator on 888.328
# A break is finished at 889.895
# Cust 53 is assigned to an expert operator at 889.895
# Cust 53 is done at expert operator on 892.947
# Cust 54 initiated a call at 895.25
# Cust 54 is assigned to an unskilled_operator at 895.25
# duration is 2.562142808204398
# Cust 54 is done at unskilled operator on 897.812
# A break is finished at 897.947
# Cust 54 is assigned to an expert operator at 897.947
# Cust 54 is done at expert operator on 898.266
# A break is finished at 903.266
# A break is finished at 908.266
# Cust 55 initiated a call at 926.3
# Cust 55 is assigned to an unskilled_operator at 926.3
# duration is 5.788268490367482
# Cust 55 is done at unskilled operator on 932.089
# Cust 55 is assigned to an expert operator at 932.089
# Cust 56 initiated a call at 940.027
# Cust 56 is assigned to an unskilled_operator at 940.027
# duration is 3.1060786076527567
# Cust 56 is done at unskilled operator on 943.133
# Cust 55 is done at expert operator on 946.441
# Cust 56 is assigned to an expert operator at 946.441
# Cust 57 initiated a call at 972.569
# Cust 57 is assigned to an unskilled_operator at 972.569
# duration is 4.971022771551308
# Cust 57 is done at unskilled operator on 977.54
# Cust 56 is done at expert operator on 985.335
# Cust 57 is assigned to an expert operator at 985.335
# Cust 57 is done at expert operator on 985.581
# Cust 58 initiated a call at 1004
# Cust 58 is assigned to an unskilled_operator at 1004
# duration is 3.7123762063309202
# Cust 58 is done at unskilled operator on 1007.71
# Cust 58 is assigned to an expert operator at 1007.71
# Cust 59 initiated a call at 1011.21
# Cust 59 is assigned to an unskilled_operator at 1011.21
# duration is 4.0272464581093645
# Cust 60 initiated a call at 1011.98
# Cust 58 is done at expert operator on 1012.51
# Cust 59 is done at unskilled operator on 1015.24
# Cust 59 is assigned to an expert operator at 1015.24
# Cust 60 is assigned to an unskilled_operator at 1015.24
# duration is 4.043798549250478
# Cust 60 is done at unskilled operator on 1019.28
# Cust 59 is done at expert operator on 1023.73
# Cust 60 is assigned to an expert operator at 1023.73
# Cust 61 initiated a call at 1026.25
# Cust 61 is assigned to an unskilled_operator at 1026.25
# duration is 4.113244497577457
# Cust 61 is done at unskilled operator on 1030.36
# Cust 60 is done at expert operator on 1038.85
# Cust 61 is assigned to an expert operator at 1038.85
# Cust 62 initiated a call at 1040.89
# Cust 62 is assigned to an unskilled_operator at 1040.89
# duration is 3.7380216418866827
# Cust 61 is done at expert operator on 1043.01
# Cust 62 is done at unskilled operator on 1044.63
# Cust 62 is assigned to an expert operator at 1044.63
# Cust 62 is done at expert operator on 1049.67
# A break is initiated at 1056
# A break is finished at 1061
# Cust 63 initiated a call at 1064.09
# Cust 63 is assigned to an unskilled_operator at 1064.09
# duration is 4.600135002140402
# Cust 63 is done at unskilled operator on 1068.69
# Cust 63 is assigned to an expert operator at 1068.69
# Cust 63 is done at expert operator on 1070.52
# Cust 64 initiated a call at 1083.13
# Cust 64 is assigned to an unskilled_operator at 1083.13
# duration is 2.5240813822527848
# Cust 64 is done at unskilled operator on 1085.65
# Cust 64 is assigned to an expert operator at 1085.65
# Cust 65 initiated a call at 1086.43
# Cust 65 is assigned to an unskilled_operator at 1086.43
# duration is 4.438958782252352
# Cust 66 initiated a call at 1087.18
# Cust 65 is done at unskilled operator on 1090.87
# Cust 66 is assigned to an unskilled_operator at 1090.87
# duration is 3.9501471465003286
# Cust 66 is done at unskilled operator on 1094.82
# A break is initiated at 1095
# Cust 64 is done at expert operator on 1100.81
# Cust 65 is assigned to an expert operator at 1100.81
# Cust 65 is done at expert operator on 1102.73
# Cust 66 is assigned to an expert operator at 1102.73
# Cust 67 initiated a call at 1111.82
# Cust 67 is assigned to an unskilled_operator at 1111.82
# duration is 2.4235902805879723
# Cust 66 is done at expert operator on 1113.01
# Cust 68 initiated a call at 1113.23
# Cust 67 is done at unskilled operator on 1114.25
# Cust 68 is assigned to an unskilled_operator at 1114.25
# duration is 5.368692041402788
# A break is finished at 1118.01
# Cust 67 is assigned to an expert operator at 1118.01
# Cust 68 is done at unskilled operator on 1119.61
# Cust 67 is done at expert operator on 1125.31
# Cust 68 is assigned to an expert operator at 1125.31
# Cust 68 is done at expert operator on 1125.49
# Cust 69 initiated a call at 1138.24
# Cust 69 is assigned to an unskilled_operator at 1138.24
# duration is 5.565414937166969
# Cust 69 is done at unskilled operator on 1143.8
# Cust 69 is assigned to an expert operator at 1143.8
# Cust 69 is done at expert operator on 1152.87
# Cust 70 initiated a call at 1172.52
# Cust 70 is assigned to an unskilled_operator at 1172.52
# duration is 6.130470948375031
# Cust 70 is done at unskilled operator on 1178.65
# Cust 70 is assigned to an expert operator at 1178.65
# Cust 70 is done at expert operator on 1182.17
# Cust 71 initiated a call at 1183.83
# Cust 71 is assigned to an unskilled_operator at 1183.83
# duration is 5.640608626430948
# Cust 71 is done at unskilled operator on 1189.47
# Cust 71 is assigned to an expert operator at 1189.47
# Cust 71 is done at expert operator on 1191.31
# Cust 72 initiated a call at 1232.48
# Cust 72 is assigned to an unskilled_operator at 1232.48
# duration is 4.87475888914951
# Cust 72 is done at unskilled operator on 1237.35
# Cust 72 is assigned to an expert operator at 1237.35
# Cust 72 is done at expert operator on 1241.39
# Cust 73 initiated a call at 1274.87
# Cust 73 is assigned to an unskilled_operator at 1274.87
# duration is 5.018439967394473
# Cust 73 is done at unskilled operator on 1279.89
# Cust 73 is assigned to an expert operator at 1279.89
# A break is initiated at 1284
# Cust 73 is done at expert operator on 1288.33
# A break is finished at 1293.33
# A break is initiated at 1305
# Cust 74 initiated a call at 1306.27
# Cust 74 is assigned to an unskilled_operator at 1306.27
# duration is 10.770306981654446
# A break is finished at 1310
# Cust 74 is done at unskilled operator on 1317.04
# Cust 74 is assigned to an expert operator at 1317.04
# Cust 74 is done at expert operator on 1320.35
# Cust 75 initiated a call at 1321.68
# Cust 75 is assigned to an unskilled_operator at 1321.68
# duration is 3.4817942871455925
# Cust 75 is done at unskilled operator on 1325.17
# Cust 75 is assigned to an expert operator at 1325.17
# Cust 76 initiated a call at 1330.79
# Cust 76 is assigned to an unskilled_operator at 1330.79
# duration is 8.336548842631858
# Cust 75 is done at expert operator on 1337.6
# Cust 76 is done at unskilled operator on 1339.13
# Cust 76 is assigned to an expert operator at 1339.13
# A break is initiated at 1342
# Cust 77 initiated a call at 1345.72
# Cust 77 is assigned to an unskilled_operator at 1345.72
# duration is 4.433333801243588
# Cust 76 is done at expert operator on 1346.47
# Cust 77 is done at unskilled operator on 1350.15
# A break is finished at 1351.47
# Cust 77 is assigned to an expert operator at 1351.47
# A break is initiated at 1354
# Cust 78 initiated a call at 1356.59
# Cust 78 is assigned to an unskilled_operator at 1356.59
# duration is 1.9130780308342015
# Cust 78 is done at unskilled operator on 1358.51
# Cust 79 initiated a call at 1364.64
# Cust 79 is assigned to an unskilled_operator at 1364.64
# duration is 4.584765144828228
# Cust 79 is done at unskilled operator on 1369.23
# Cust 77 is done at expert operator on 1372.76
# Cust 78 is assigned to an expert operator at 1372.76
# Cust 78 is done at expert operator on 1377.97
# Cust 79 is assigned to an expert operator at 1377.97
# Cust 79 is done at expert operator on 1384.93
# A break is initiated at 1385
# Cust 80 initiated a call at 1389.62
# Cust 80 is assigned to an unskilled_operator at 1389.62
# duration is 3.2899820677521827
# A break is finished at 1389.93
# Cust 80 is done at unskilled operator on 1392.91
# Cust 81 initiated a call at 1393.42
# Cust 81 is assigned to an unskilled_operator at 1393.42
# duration is 2.8064293086891863
# A break is finished at 1394.93
# Cust 80 is assigned to an expert operator at 1394.93
# Cust 82 initiated a call at 1395.37
# Cust 81 is done at unskilled operator on 1396.23
# Cust 82 is assigned to an unskilled_operator at 1396.23
# duration is 2.6075656950585984
# Cust 82 is done at unskilled operator on 1398.83
# A break is initiated at 1404
# Cust 83 initiated a call at 1405.45
# Cust 83 is assigned to an unskilled_operator at 1405.45
# duration is 2.430399802503657
# Cust 83 is done at unskilled operator on 1407.88
# A break is initiated at 1408
# Cust 84 initiated a call at 1420.63
# Cust 84 is assigned to an unskilled_operator at 1420.63
# duration is 3.304712006907648
# Cust 85 initiated a call at 1423.45
# Cust 80 is done at expert operator on 1423.78
# Cust 81 is assigned to an expert operator at 1423.78
# Cust 84 is done at unskilled operator on 1423.94
# Cust 85 is assigned to an unskilled_operator at 1423.94
# duration is 1.7947461911982874
# Cust 81 is done at expert operator on 1424.15
# Cust 82 is assigned to an expert operator at 1424.15
# Cust 85 is done at unskilled operator on 1425.73
# Cust 82 is done at expert operator on 1425.78
# Cust 83 is assigned to an expert operator at 1425.78
# Cust 86 initiated a call at 1430.9
# Cust 86 is assigned to an unskilled_operator at 1430.9
# duration is 3.7264959430902227
# Cust 87 initiated a call at 1431.53
# Cust 86 is done at unskilled operator on 1434.63
# Cust 87 is assigned to an unskilled_operator at 1434.63
# duration is 2.7000818491249174
# Cust 88 initiated a call at 1437.22
# Cust 87 is done at unskilled operator on 1437.33
# Cust 88 is assigned to an unskilled_operator at 1437.33
# duration is 8.161057697325827
# Cust 88 is done at unskilled operator on 1445.49
# Cust 83 is done at expert operator on 1446.32
# Cust 84 is assigned to an expert operator at 1446.32
# A break is initiated at 1448
# Cust 89 initiated a call at 1450.43
# Cust 89 is assigned to an unskilled_operator at 1450.43
# duration is 5.23329896899458
# Cust 84 is done at expert operator on 1451.29
# Cust 85 is assigned to an expert operator at 1451.29
# Cust 89 is done at unskilled operator on 1455.67
# Cust 85 is done at expert operator on 1457.11
# Cust 86 is assigned to an expert operator at 1457.11
# Cust 86 is done at expert operator on 1461.32
# Cust 87 is assigned to an expert operator at 1461.32
# Cust 87 is done at expert operator on 1473.04
# Cust 88 is assigned to an expert operator at 1473.04
# Cust 88 is done at expert operator on 1473.62
# Cust 89 is assigned to an expert operator at 1473.62
# Cust 90 initiated a call at 1486.24
# Cust 90 is assigned to an unskilled_operator at 1486.24
# duration is 6.353993606400133
# Cust 89 is done at expert operator on 1488.86
# Cust 90 is done at unskilled operator on 1492.59
# A break is finished at 1493.86
# Cust 90 is assigned to an expert operator at 1493.86
# Cust 91 initiated a call at 1496.45
# Cust 91 is assigned to an unskilled_operator at 1496.45
# duration is 3.4392633778134436
# A break is initiated at 1498
# Cust 91 is done at unskilled operator on 1499.89
# Cust 92 initiated a call at 1500.84
# Cust 92 is assigned to an unskilled_operator at 1500.84
# duration is 4.4298595860150005
# A break is initiated at 1503
# Cust 92 is done at unskilled operator on 1505.27
# Cust 90 is done at expert operator on 1508.9
# Cust 91 is assigned to an expert operator at 1508.9
# Cust 93 initiated a call at 1509.23
# Cust 93 is assigned to an unskilled_operator at 1509.23
# duration is 3.7058551500111654
# Cust 93 is done at unskilled operator on 1512.94
# Cust 91 is done at expert operator on 1516.42
# Cust 92 is assigned to an expert operator at 1516.42
# Cust 92 is done at expert operator on 1517.28
# Cust 93 is assigned to an expert operator at 1517.28
# Cust 93 is done at expert operator on 1521.47
# Cust 94 initiated a call at 1522.99
# Cust 94 is assigned to an unskilled_operator at 1522.99
# duration is 3.851917811892487
# Cust 95 initiated a call at 1526.28
# A break is finished at 1526.47
# Cust 94 is done at unskilled operator on 1526.84
# Cust 95 is assigned to an unskilled_operator at 1526.84
# duration is 4.702846322142275
# Cust 96 initiated a call at 1529.46
# A break is finished at 1531.47
# Cust 94 is assigned to an expert operator at 1531.47
# Cust 95 is done at unskilled operator on 1531.54
# Cust 96 is assigned to an unskilled_operator at 1531.54
# duration is 4.46783801208274
# Cust 96 is done at unskilled operator on 1536.01
# Cust 97 initiated a call at 1537.7
# Cust 97 is assigned to an unskilled_operator at 1537.7
# duration is 3.4838183749697507
# Cust 97 is done at unskilled operator on 1541.18
# Cust 98 initiated a call at 1541.61
# Cust 98 is assigned to an unskilled_operator at 1541.61
# duration is 3.2830159921719853
# Cust 94 is done at expert operator on 1543.29
# Cust 95 is assigned to an expert operator at 1543.29
# Cust 98 is done at unskilled operator on 1544.89
# Cust 99 initiated a call at 1555.54
# Cust 99 is assigned to an unskilled_operator at 1555.54
# duration is 1.2154077407828874
# Cust 99 is done at unskilled operator on 1556.76
# A break is initiated at 1558
# Cust 95 is done at expert operator on 1560.31
# Cust 96 is assigned to an expert operator at 1560.31
# Cust 96 is done at expert operator on 1565.91
# Cust 97 is assigned to an expert operator at 1565.91
# Cust 97 is done at expert operator on 1566.94
# Cust 98 is assigned to an expert operator at 1566.94
# Cust 98 is done at expert operator on 1567.15
# Cust 99 is assigned to an expert operator at 1567.15
# A break is initiated at 1571
# Cust 99 is done at expert operator on 1571.21
# A break is finished at 1576.21
# Cust 100 initiated a call at 1578.86
# Cust 100 is assigned to an unskilled_operator at 1578.86
# duration is 3.614772228496301
# Cust 101 initiated a call at 1580.15
# A break is finished at 1581.21
# Cust 102 initiated a call at 1582.31
# Cust 103 initiated a call at 1582.4
# Cust 100 is done at unskilled operator on 1582.48
# Cust 101 is assigned to an unskilled_operator at 1582.48
# duration is 6.112779993356531
# A break is finished at 1586.21
# Cust 100 is assigned to an expert operator at 1586.21
# Cust 104 initiated a call at 1587.21
# Cust 101 is done at unskilled operator on 1588.59
# Cust 102 is assigned to an unskilled_operator at 1588.59
# duration is 1.6480451266079883
# Cust 102 is done at unskilled operator on 1590.24
# Cust 103 is assigned to an unskilled_operator at 1590.24
# duration is 3.66218609265323
# Cust 105 initiated a call at 1591.09
# Cust 103 is done at unskilled operator on 1593.9
# Cust 104 is assigned to an unskilled_operator at 1593.9
# duration is 6.121743068068425
# Cust 100 is done at expert operator on 1598.93
# Cust 101 is assigned to an expert operator at 1598.93
# Cust 104 is done at unskilled operator on 1600.02
# Cust 105 is assigned to an unskilled_operator at 1600.02
# duration is 4.812414222735587
# Cust 101 is done at expert operator on 1603.54
# Cust 102 is assigned to an expert operator at 1603.54
# Cust 102 is done at expert operator on 1603.97
# Cust 103 is assigned to an expert operator at 1603.97
# Cust 105 is done at unskilled operator on 1604.84
# Cust 106 initiated a call at 1607.39
# Cust 106 is assigned to an unskilled_operator at 1607.39
# duration is 3.6968450905098287
# Cust 107 initiated a call at 1610.27
# Cust 106 is done at unskilled operator on 1611.09
# Cust 107 is assigned to an unskilled_operator at 1611.09
# duration is 3.9432322833285745
# Cust 107 is done at unskilled operator on 1615.03
# Cust 103 is done at expert operator on 1625.82
# Cust 104 is assigned to an expert operator at 1625.82
# Cust 108 initiated a call at 1630.48
# Cust 108 is assigned to an unskilled_operator at 1630.48
# duration is 3.5871226495898343
# Cust 104 is done at expert operator on 1631.77
# Cust 105 is assigned to an expert operator at 1631.77
# Cust 108 is done at unskilled operator on 1634.06
# Cust 105 is done at expert operator on 1637.13
# Cust 106 is assigned to an expert operator at 1637.13
# Cust 106 is done at expert operator on 1640.43
# Cust 107 is assigned to an expert operator at 1640.43
# Cust 107 is done at expert operator on 1644.98
# Cust 108 is assigned to an expert operator at 1644.98
# Cust 108 is done at expert operator on 1653.76
# A break is finished at 1658.76
# Cust 109 initiated a call at 1665.28
# Cust 109 is assigned to an unskilled_operator at 1665.28
# duration is 4.477285478049471
# A break is initiated at 1666
# Cust 110 initiated a call at 1667.11
# Cust 109 is done at unskilled operator on 1669.76
# Cust 110 is assigned to an unskilled_operator at 1669.76
# duration is 4.350621680297883
# A break is finished at 1671
# Cust 109 is assigned to an expert operator at 1671
# Cust 110 is done at unskilled operator on 1674.11
# Cust 111 initiated a call at 1677.84
# Cust 111 is assigned to an unskilled_operator at 1677.84
# duration is 4.80232505464715
# Cust 111 is done at unskilled operator on 1682.64
# Cust 112 initiated a call at 1691.86
# Cust 112 is assigned to an unskilled_operator at 1691.86
# duration is 4.955963302937377
# Cust 109 is done at expert operator on 1694.73
# Cust 110 is assigned to an expert operator at 1694.73
# Cust 112 is done at unskilled operator on 1696.82
# Cust 113 initiated a call at 1701.87
# Cust 113 is assigned to an unskilled_operator at 1701.87
# duration is 4.275414927036227
# Cust 110 is done at expert operator on 1705.17
# Cust 111 is assigned to an expert operator at 1705.17
# Cust 113 is done at unskilled operator on 1706.14
# Cust 114 initiated a call at 1730.63
# Cust 114 is assigned to an unskilled_operator at 1730.63
# duration is 1.796811092024245
# Cust 114 is done at unskilled operator on 1732.42
# Cust 111 is done at expert operator on 1733.44
# Cust 112 is assigned to an expert operator at 1733.44
# Cust 112 is done at expert operator on 1734.99
# Cust 113 is assigned to an expert operator at 1734.99
# Cust 113 is done at expert operator on 1735.33
# Cust 114 is assigned to an expert operator at 1735.33
# Cust 115 initiated a call at 1740.86
# Cust 115 is assigned to an unskilled_operator at 1740.86
# duration is 4.1009566038791
# A break is initiated at 1744
# Cust 114 is done at expert operator on 1744.78
# Cust 115 is done at unskilled operator on 1744.96
# A break is finished at 1749.78
# Cust 115 is assigned to an expert operator at 1749.78
# Cust 116 initiated a call at 1761.84
# Cust 116 is assigned to an unskilled_operator at 1761.84
# duration is 1.7799461089757767
# Cust 116 is done at unskilled operator on 1763.62
# Cust 117 initiated a call at 1766.74
# Cust 117 is assigned to an unskilled_operator at 1766.74
# duration is 5.446584800960076
# Cust 117 is done at unskilled operator on 1772.19
# Cust 115 is done at expert operator on 1781.61
# Cust 116 is assigned to an expert operator at 1781.61
# Cust 116 is done at expert operator on 1781.65
# Cust 117 is assigned to an expert operator at 1781.65
# Cust 117 is done at expert operator on 1787.75
# A break is initiated at 1809
# A break is finished at 1814
# Cust 118 initiated a call at 1814.46
# Cust 118 is assigned to an unskilled_operator at 1814.46
# duration is 5.868834526802034
# Cust 119 initiated a call at 1815.9
# Cust 118 is done at unskilled operator on 1820.33
# Cust 118 is assigned to an expert operator at 1820.33
# Cust 119 is assigned to an unskilled_operator at 1820.33
# duration is 6.898063089674094
# Cust 118 is done at expert operator on 1824.2
# Cust 119 is done at unskilled operator on 1827.22
# Cust 119 is assigned to an expert operator at 1827.22
# Cust 120 initiated a call at 1835.46
# Cust 120 is assigned to an unskilled_operator at 1835.46
# duration is 6.47934627091246
# Cust 121 initiated a call at 1836.14
# Cust 120 is done at unskilled operator on 1841.94
# Cust 121 is assigned to an unskilled_operator at 1841.94
# duration is 5.112107195704034
# Cust 119 is done at expert operator on 1844.15
# Cust 120 is assigned to an expert operator at 1844.15
# Cust 121 is done at unskilled operator on 1847.05
# Cust 120 is done at expert operator on 1848.94
# Cust 121 is assigned to an expert operator at 1848.94
# Cust 121 is done at expert operator on 1849.78
# A break is initiated at 1894
# A break is finished at 1899
# A break is initiated at 1906
# A break is finished at 1911
# Cust 122 initiated a call at 1918.42
# Cust 122 is assigned to an unskilled_operator at 1918.42
# duration is 4.094153400394111
# Cust 122 is done at unskilled operator on 1922.52
# Cust 122 is assigned to an expert operator at 1922.52
# Cust 122 is done at expert operator on 1934.43
# Cust 123 initiated a call at 1942.47
# Cust 123 is assigned to an unskilled_operator at 1942.47
# duration is 3.2927013831384686
# Cust 123 is done at unskilled operator on 1945.76
# Cust 123 is assigned to an expert operator at 1945.76
# A break is initiated at 1950
# Cust 123 is done at expert operator on 1960.84
# A break is finished at 1965.84
# Cust 124 initiated a call at 1979.67
# Cust 124 is assigned to an unskilled_operator at 1979.67
# duration is 6.324175712881402
# Cust 125 initiated a call at 1979.86
# Cust 126 initiated a call at 1983.74
# Cust 124 is done at unskilled operator on 1986
# Cust 124 is assigned to an expert operator at 1986
# Cust 125 is assigned to an unskilled_operator at 1986
# duration is 4.5353551371559595
# Cust 125 is done at unskilled operator on 1990.53
# Cust 126 is assigned to an unskilled_operator at 1990.53
# duration is 1.998857677080009
# Cust 124 is done at expert operator on 1992.17
# Cust 125 is assigned to an expert operator at 1992.17
# Cust 126 is done at unskilled operator on 1992.53
# Cust 125 is done at expert operator on 2001.52
# Cust 126 is assigned to an expert operator at 2001.52
# Cust 127 initiated a call at 2005.91
# Cust 127 is assigned to an unskilled_operator at 2005.91
# duration is 2.9457673990701463
# Cust 127 is done at unskilled operator on 2008.85
# Cust 126 is done at expert operator on 2012.15
# Cust 127 is assigned to an expert operator at 2012.15
# Cust 128 initiated a call at 2018.44
# Cust 128 is assigned to an unskilled_operator at 2018.44
# duration is 4.189466282031344
# Cust 129 initiated a call at 2020.67
# Cust 128 is done at unskilled operator on 2022.63
# Cust 129 is assigned to an unskilled_operator at 2022.63
# duration is 2.811161618034208
# Cust 129 is done at unskilled operator on 2025.44
# Cust 130 initiated a call at 2027
# Cust 130 is assigned to an unskilled_operator at 2027
# duration is 5.438925429864977
# Cust 131 initiated a call at 2028.9
# Cust 130 is done at unskilled operator on 2032.44
# Cust 131 is assigned to an unskilled_operator at 2032.44
# duration is 7.105630652102169
# A break is initiated at 2033
# Cust 131 is done at unskilled operator on 2039.54
# Cust 127 is done at expert operator on 2054.76
# Cust 128 is assigned to an expert operator at 2054.76
# Cust 132 initiated a call at 2056.92
# Cust 132 is assigned to an unskilled_operator at 2056.92
# duration is 5.6709577847948935
# Cust 132 is done at unskilled operator on 2062.59
# Cust 133 initiated a call at 2068.2
# Cust 133 is assigned to an unskilled_operator at 2068.2
# duration is 4.758294435000355
# Cust 134 initiated a call at 2068.43
# Cust 133 is done at unskilled operator on 2072.96
# Cust 134 is assigned to an unskilled_operator at 2072.96
# duration is 6.459196267792385
# A break is initiated at 2074
# Cust 135 initiated a call at 2076.55
# Cust 136 initiated a call at 2079.17
# Cust 134 is done at unskilled operator on 2079.42
# Cust 135 is assigned to an unskilled_operator at 2079.42
# duration is 3.5708676698623543
# Cust 128 is done at expert operator on 2080.49
# Cust 129 is assigned to an expert operator at 2080.49
# Cust 135 is done at unskilled operator on 2082.99
# Cust 136 is assigned to an unskilled_operator at 2082.99
# duration is 7.608926192954994
# Cust 129 is done at expert operator on 2084.47
# Cust 130 is assigned to an expert operator at 2084.47
# A break is initiated at 2087
# Cust 130 is done at expert operator on 2087.84
# Cust 131 is assigned to an expert operator at 2087.84
# Cust 131 is done at expert operator on 2087.9
# Cust 132 is assigned to an expert operator at 2087.9
# Cust 137 initiated a call at 2088.69
# Cust 136 is done at unskilled operator on 2090.6
# Cust 137 is assigned to an unskilled_operator at 2090.6
# duration is 3.4448500647247995
# Cust 137 is done at unskilled operator on 2094.04
# Cust 132 is done at expert operator on 2097.87
# Cust 133 is assigned to an expert operator at 2097.87
# Cust 133 is done at expert operator on 2102.33
# Cust 134 is assigned to an expert operator at 2102.33
# Cust 138 initiated a call at 2113.24
# Cust 138 is assigned to an unskilled_operator at 2113.24
# duration is 4.500798658659169
# Cust 134 is done at expert operator on 2117.22
# Cust 135 is assigned to an expert operator at 2117.22
# Cust 138 is done at unskilled operator on 2117.74
# Cust 139 initiated a call at 2122.66
# Cust 139 is assigned to an unskilled_operator at 2122.66
# duration is 4.384676180273586
# Cust 135 is done at expert operator on 2123.97
# Cust 136 is assigned to an expert operator at 2123.97
# Cust 136 is done at expert operator on 2126
# Cust 137 is assigned to an expert operator at 2126
# Cust 137 is done at expert operator on 2126.13
# Cust 138 is assigned to an expert operator at 2126.13
# Cust 139 is done at unskilled operator on 2127.05
# Cust 138 is done at expert operator on 2132.06
# Cust 139 is assigned to an expert operator at 2132.06
# Cust 140 initiated a call at 2135.29
# Cust 140 is assigned to an unskilled_operator at 2135.29
# duration is 5.335460478398378
# Cust 140 is done at unskilled operator on 2140.62
# A break is initiated at 2141
# Cust 139 is done at expert operator on 2145.93
# Cust 140 is assigned to an expert operator at 2145.93
# Cust 140 is done at expert operator on 2151.85
# A break is initiated at 2154
# A break is finished at 2156.85
# A break is finished at 2161.85
# Cust 141 initiated a call at 2162.67
# Cust 141 is assigned to an unskilled_operator at 2162.67
# duration is 5.2250726428933865
# A break is finished at 2166.85
# Cust 141 is done at unskilled operator on 2167.89
# A break is finished at 2171.85
# Cust 141 is assigned to an expert operator at 2171.85
# Cust 142 initiated a call at 2173.2
# Cust 142 is assigned to an unskilled_operator at 2173.2
# duration is 4.399975460792699
# Cust 143 initiated a call at 2173.23
# Cust 142 is done at unskilled operator on 2177.6
# Cust 143 is assigned to an unskilled_operator at 2177.6
# duration is 4.090313740417152
# Cust 144 initiated a call at 2180.88
# Cust 143 is done at unskilled operator on 2181.7
# Cust 144 is assigned to an unskilled_operator at 2181.7
# duration is 3.00210353356045
# Cust 144 is done at unskilled operator on 2184.7
# Cust 141 is done at expert operator on 2184.83
# Cust 142 is assigned to an expert operator at 2184.83
# Cust 142 is done at expert operator on 2188.33
# Cust 143 is assigned to an expert operator at 2188.33
# Cust 143 is done at expert operator on 2190.18
# Cust 144 is assigned to an expert operator at 2190.18
# Cust 144 is done at expert operator on 2213.73
# Cust 145 initiated a call at 2218.68
# Cust 145 is assigned to an unskilled_operator at 2218.68
# duration is 2.095347443536763
# A break is finished at 2218.73
# Cust 145 is done at unskilled operator on 2220.77
# Cust 145 is assigned to an expert operator at 2220.77
# Cust 146 initiated a call at 2232.66
# Cust 146 is assigned to an unskilled_operator at 2232.66
# duration is 6.683179050768141
# Cust 147 initiated a call at 2235.03
# Cust 146 is done at unskilled operator on 2239.35
# Cust 147 is assigned to an unskilled_operator at 2239.35
# duration is 4.306747976928994
# Cust 147 is done at unskilled operator on 2243.65
# Cust 145 is done at expert operator on 2249.03
# Cust 146 is assigned to an expert operator at 2249.03
# Cust 146 is done at expert operator on 2255.79
# Cust 147 is assigned to an expert operator at 2255.79
# Cust 147 is done at expert operator on 2255.93
# Cust 148 initiated a call at 2270.64
# Cust 148 is assigned to an unskilled_operator at 2270.64
# duration is 4.109118699055908
# Cust 148 is done at unskilled operator on 2274.75
# Cust 148 is assigned to an expert operator at 2274.75
# Cust 149 initiated a call at 2279.61
# Cust 149 is assigned to an unskilled_operator at 2279.61
# duration is 3.2969239510846444
# Cust 149 is done at unskilled operator on 2282.91
# Cust 148 is done at expert operator on 2283.47
# Cust 149 is assigned to an expert operator at 2283.47
# Cust 149 is done at expert operator on 2283.97
# Cust 150 initiated a call at 2310.44
# Cust 150 is assigned to an unskilled_operator at 2310.44
# duration is 5.46112315633844
# Cust 151 initiated a call at 2310.86
# Cust 150 is done at unskilled operator on 2315.9
# Cust 150 is assigned to an expert operator at 2315.9
# Cust 151 is assigned to an unskilled_operator at 2315.9
# duration is 3.5644478513716447
# Cust 151 is done at unskilled operator on 2319.47
# Cust 152 initiated a call at 2335.11
# Cust 152 is assigned to an unskilled_operator at 2335.11
# duration is 4.386516128138123
# Cust 150 is done at expert operator on 2335.15
# Cust 151 is assigned to an expert operator at 2335.15
# Cust 151 is done at expert operator on 2337.66
# Cust 152 is done at unskilled operator on 2339.5
# Cust 152 is assigned to an expert operator at 2339.5
# Cust 152 is done at expert operator on 2343.15
# Cust 153 initiated a call at 2377.67
# Cust 153 is assigned to an unskilled_operator at 2377.67
# duration is 4.498486733119586
# Cust 153 is done at unskilled operator on 2382.17
# Cust 153 is assigned to an expert operator at 2382.17
# Cust 153 is done at expert operator on 2383.63
# Cust 154 initiated a call at 2406.11
# Cust 154 is assigned to an unskilled_operator at 2406.11
# duration is 4.447609526677158
# Cust 154 is done at unskilled operator on 2410.56
# Cust 154 is assigned to an expert operator at 2410.56
# Cust 154 is done at expert operator on 2413.35
# A break is initiated at 2420
# A break is initiated at 2425
# A break is finished at 2425
# A break is finished at 2430
# Cust 155 initiated a call at 2454.65
# Cust 155 is assigned to an unskilled_operator at 2454.65
# duration is 2.3525486062525056
# Cust 155 is done at unskilled operator on 2457.01
# Cust 155 is assigned to an expert operator at 2457.01
# Cust 156 initiated a call at 2458.55
# Cust 156 is assigned to an unskilled_operator at 2458.55
# duration is 6.3955970596187575
# Cust 156 is done at unskilled operator on 2464.94
# Cust 157 initiated a call at 2469.8
# Cust 157 is assigned to an unskilled_operator at 2469.8
# duration is 6.026651386279216
# Cust 155 is done at expert operator on 2471.1
# Cust 156 is assigned to an expert operator at 2471.1
# Cust 156 is done at expert operator on 2471.36
# Cust 157 is done at unskilled operator on 2475.82
# Cust 157 is assigned to an expert operator at 2475.82
# Cust 157 is done at expert operator on 2492.72
# Cust 158 initiated a call at 2522.58
# Cust 158 is assigned to an unskilled_operator at 2522.58
# duration is 5.218997304217121
# Cust 158 is done at unskilled operator on 2527.8
# Cust 158 is assigned to an expert operator at 2527.8
# Cust 158 is done at expert operator on 2530.08
# Cust 159 initiated a call at 2539.92
# Cust 159 is assigned to an unskilled_operator at 2539.92
# duration is 4.315275379647853
# Cust 159 is done at unskilled operator on 2544.23
# Cust 159 is assigned to an expert operator at 2544.23
# Cust 159 is done at expert operator on 2550.86
# Cust 160 initiated a call at 2571.87
# Cust 160 is assigned to an unskilled_operator at 2571.87
# duration is 3.629142400123742
# Cust 160 is done at unskilled operator on 2575.49
# Cust 160 is assigned to an expert operator at 2575.49
# Cust 160 is done at expert operator on 2578.88
# Cust 161 initiated a call at 2601.33
# Cust 161 is assigned to an unskilled_operator at 2601.33
# duration is 2.5531445012819702
# Cust 161 is done at unskilled operator on 2603.88
# Cust 161 is assigned to an expert operator at 2603.88
# Cust 161 is done at expert operator on 2620.95
# A break is initiated at 2622
# A break is finished at 2627
# A break is initiated at 2674
# A break is finished at 2679
# A break is initiated at 2680
# Cust 162 initiated a call at 2680.21
# Cust 162 is assigned to an unskilled_operator at 2680.21
# duration is 4.4426762697167215
# Cust 163 initiated a call at 2683.04
# Cust 162 is done at unskilled operator on 2684.66
# Cust 163 is assigned to an unskilled_operator at 2684.66
# duration is 4.347455401996481
# A break is finished at 2685
# Cust 162 is assigned to an expert operator at 2685
# Cust 163 is done at unskilled operator on 2689
# Cust 162 is done at expert operator on 2690.2
# Cust 163 is assigned to an expert operator at 2690.2
# Cust 164 initiated a call at 2693.38
# Cust 164 is assigned to an unskilled_operator at 2693.38
# duration is 3.9649870303740977
# Cust 164 is done at unskilled operator on 2697.35
# Cust 163 is done at expert operator on 2727.16
# Cust 164 is assigned to an expert operator at 2727.16
# Cust 164 is done at expert operator on 2732.59
# Cust 165 initiated a call at 2733.27
# Cust 165 is assigned to an unskilled_operator at 2733.27
# duration is 3.8221838225678186
# Cust 166 initiated a call at 2734.4
# Cust 165 is done at unskilled operator on 2737.09
# Cust 165 is assigned to an expert operator at 2737.09
# Cust 166 is assigned to an unskilled_operator at 2737.09
# duration is 2.244936644882336
# Cust 166 is done at unskilled operator on 2739.34
# Cust 165 is done at expert operator on 2739.96
# Cust 166 is assigned to an expert operator at 2739.96
# Cust 166 is done at expert operator on 2742.65
# Cust 167 initiated a call at 2745.17
# Cust 167 is assigned to an unskilled_operator at 2745.17
# duration is 3.6634546704393705
# Cust 167 is done at unskilled operator on 2748.84
# Cust 167 is assigned to an expert operator at 2748.84
# Cust 167 is done at expert operator on 2755.85
# A break is initiated at 2782
# Cust 168 initiated a call at 2782.64
# ...
# Cust 943 is done at expert operator on 14936
# Cust 944 is assigned to an expert operator at 14936
# Cust 944 is done at expert operator on 14936.8
# Cust 945 is assigned to an expert operator at 14936.8
# Cust 947 initiated a call at 14940.4
# Cust 947 is assigned to an unskilled_operator at 14940.4
# duration is 1.6557914817347683
# Cust 948 initiated a call at 14940.4
# Cust 947 is done at unskilled operator on 14942
# Cust 948 is assigned to an unskilled_operator at 14942
# duration is 3.2123879362578442
# Cust 949 initiated a call at 14943.1
# Cust 948 is done at unskilled operator on 14945.2
# Cust 949 is assigned to an unskilled_operator at 14945.2
# duration is 2.743431180678953
# Cust 945 is done at expert operator on 14946.4
# Cust 946 is assigned to an expert operator at 14946.4
# Cust 949 is done at unskilled operator on 14948
# Cust 946 is done at expert operator on 14956.5
# Cust 947 is assigned to an expert operator at 14956.5
# Cust 947 is done at expert operator on 14962.2
# Cust 948 is assigned to an expert operator at 14962.2
# Cust 948 is done at expert operator on 14966.7
# Cust 949 is assigned to an expert operator at 14966.7
# Cust 949 is done at expert operator on 14976.1
# A break is finished at 14981.1
# A break is finished at 14986.1
# A break is initiated at 14994
# Cust 950 initiated a call at 14997.5
# Cust 950 is assigned to an unskilled_operator at 14997.5
# duration is 4.223664097687517
# A break is finished at 14999
# Cust 950 is done at unskilled operator on 15001.7
# Cust 950 is assigned to an expert operator at 15001.7
# A break is initiated at 15002
# Cust 950 is done at expert operator on 15013.1
# Cust 951 initiated a call at 15014.5
# Cust 951 is assigned to an unskilled_operator at 15014.5
# duration is 3.671515221365204
# A break is finished at 15018.1
# Cust 951 is done at unskilled operator on 15018.2
# Cust 951 is assigned to an expert operator at 15018.2
# Cust 952 initiated a call at 15019.8
# Cust 952 is assigned to an unskilled_operator at 15019.8
# duration is 4.497996946762844
# Cust 951 is done at expert operator on 15022.6
# Cust 953 initiated a call at 15023.6
# Cust 952 is done at unskilled operator on 15024.3
# Cust 952 is assigned to an expert operator at 15024.3
# Cust 953 is assigned to an unskilled_operator at 15024.3
# duration is 2.8857413637290574
# Cust 953 is done at unskilled operator on 15027.2
# Cust 952 is done at expert operator on 15037.3
# Cust 953 is assigned to an expert operator at 15037.3
# Cust 953 is done at expert operator on 15043.5
# Cust 954 initiated a call at 15045.5
# Cust 954 is assigned to an unskilled_operator at 15045.5
# duration is 4.968846772489548
# Cust 954 is done at unskilled operator on 15050.5
# Cust 954 is assigned to an expert operator at 15050.5
# Cust 955 initiated a call at 15051.7
# Cust 955 is assigned to an unskilled_operator at 15051.7
# duration is 7.926582264992438
# Cust 955 is done at unskilled operator on 15059.6
# Cust 954 is done at expert operator on 15061.9
# Cust 955 is assigned to an expert operator at 15061.9
# Cust 955 is done at expert operator on 15069.2
# A break is initiated at 15070
# A break is finished at 15075
# Cust 956 initiated a call at 15080.7
# Cust 956 is assigned to an unskilled_operator at 15080.7
# duration is 3.109077716994163
# Cust 956 is done at unskilled operator on 15083.8
# Cust 956 is assigned to an expert operator at 15083.8
# Cust 956 is done at expert operator on 15091.3
# A break is initiated at 15103
# Cust 957 initiated a call at 15107.2
# Cust 957 is assigned to an unskilled_operator at 15107.2
# duration is 5.340901410122144
# A break is finished at 15108
# Cust 957 is done at unskilled operator on 15112.6
# Cust 957 is assigned to an expert operator at 15112.6
# Cust 957 is done at expert operator on 15115.9
# Cust 958 initiated a call at 15122.2
# Cust 958 is assigned to an unskilled_operator at 15122.2
# duration is 4.115141484761438
# Cust 958 is done at unskilled operator on 15126.3
# Cust 958 is assigned to an expert operator at 15126.3
# Cust 958 is done at expert operator on 15133.1
# Cust 959 initiated a call at 15138.3
# Cust 959 is assigned to an unskilled_operator at 15138.3
# duration is 6.338018117857338
# Cust 960 initiated a call at 15141.5
# Cust 959 is done at unskilled operator on 15144.6
# Cust 959 is assigned to an expert operator at 15144.6
# Cust 960 is assigned to an unskilled_operator at 15144.6
# duration is 7.001550809653407
# Cust 959 is done at expert operator on 15148.3
# Cust 961 initiated a call at 15150.4
# Cust 960 is done at unskilled operator on 15151.6
# Cust 960 is assigned to an expert operator at 15151.6
# Cust 961 is assigned to an unskilled_operator at 15151.6
# duration is 2.672062322537104
# Cust 961 is done at unskilled operator on 15154.3
# Cust 960 is done at expert operator on 15164.3
# Cust 961 is assigned to an expert operator at 15164.3
# Cust 961 is done at expert operator on 15164.7
# Cust 962 initiated a call at 15166.8
# Cust 962 is assigned to an unskilled_operator at 15166.8
# duration is 3.8649556903856057
# A break is initiated at 15167
# Cust 962 is done at unskilled operator on 15170.7
# A break is finished at 15172
# Cust 962 is assigned to an expert operator at 15172
# Cust 962 is done at expert operator on 15175.4
# Cust 963 initiated a call at 15203.6
# Cust 963 is assigned to an unskilled_operator at 15203.6
# duration is 4.827469790597755
# Cust 963 is done at unskilled operator on 15208.5
# Cust 963 is assigned to an expert operator at 15208.5
# Cust 963 is done at expert operator on 15209.4
# Cust 964 initiated a call at 15248.6
# Cust 964 is assigned to an unskilled_operator at 15248.6
# duration is 0.4853602355072244
# Cust 964 is done at unskilled operator on 15249.1
# Cust 964 is assigned to an expert operator at 15249.1
# Cust 965 initiated a call at 15254.3
# Cust 965 is assigned to an unskilled_operator at 15254.3
# duration is 4.345327356408767
# Cust 964 is done at expert operator on 15258.6
# Cust 965 is done at unskilled operator on 15258.7
# Cust 965 is assigned to an expert operator at 15258.7
# Cust 966 initiated a call at 15265.2
# Cust 966 is assigned to an unskilled_operator at 15265.2
# duration is 5.726543909531711
# Cust 967 initiated a call at 15265.6
# Cust 966 is done at unskilled operator on 15270.9
# Cust 967 is assigned to an unskilled_operator at 15270.9
# duration is 3.565515979873075
# Cust 967 is done at unskilled operator on 15274.5
# Cust 965 is done at expert operator on 15285.3
# Cust 966 is assigned to an expert operator at 15285.3
# Cust 966 is done at expert operator on 15295.9
# Cust 967 is assigned to an expert operator at 15295.9
# Cust 967 is done at expert operator on 15300.9
# Cust 968 initiated a call at 15305.2
# Cust 968 is assigned to an unskilled_operator at 15305.2
# duration is 5.4269731076800465
# Cust 968 is done at unskilled operator on 15310.6
# Cust 968 is assigned to an expert operator at 15310.6
# Cust 969 initiated a call at 15311.8
# Cust 969 is assigned to an unskilled_operator at 15311.8
# duration is 5.512850445136016
# Cust 969 is done at unskilled operator on 15317.4
# A break is initiated at 15326
# Cust 968 is done at expert operator on 15363.6
# Cust 969 is assigned to an expert operator at 15363.6
# Cust 970 initiated a call at 15365.3
# Cust 970 is assigned to an unskilled_operator at 15365.3
# duration is 5.759299956374181
# Cust 969 is done at expert operator on 15367.8
# A break is initiated at 15371
# Cust 970 is done at unskilled operator on 15371.1
# A break is finished at 15372.8
# Cust 970 is assigned to an expert operator at 15372.8
# Cust 970 is done at expert operator on 15381.4
# A break is finished at 15386.4
# Cust 971 initiated a call at 15401.4
# Cust 971 is assigned to an unskilled_operator at 15401.4
# duration is 6.1738729097598775
# Cust 972 initiated a call at 15402.5
# Cust 971 is done at unskilled operator on 15407.6
# Cust 971 is assigned to an expert operator at 15407.6
# Cust 972 is assigned to an unskilled_operator at 15407.6
# duration is 6.283102049871278
# Cust 971 is done at expert operator on 15408.5
# Cust 972 is done at unskilled operator on 15413.9
# Cust 972 is assigned to an expert operator at 15413.9
# Cust 972 is done at expert operator on 15420.6
# Cust 973 initiated a call at 15420.6
# Cust 973 is assigned to an unskilled_operator at 15420.6
# duration is 4.892993718657355
# Cust 974 initiated a call at 15424.1
# Cust 973 is done at unskilled operator on 15425.5
# Cust 973 is assigned to an expert operator at 15425.5
# Cust 974 is assigned to an unskilled_operator at 15425.5
# duration is 3.40396392925636
# Cust 975 initiated a call at 15427.3
# Cust 976 initiated a call at 15428.5
# Cust 974 is done at unskilled operator on 15428.9
# Cust 975 is assigned to an unskilled_operator at 15428.9
# duration is 3.7577516062915253
# Cust 975 is done at unskilled operator on 15432.7
# Cust 976 is assigned to an unskilled_operator at 15432.7
# duration is 5.1130071141296645
# Cust 973 is done at expert operator on 15433.4
# Cust 974 is assigned to an expert operator at 15433.4
# Cust 974 is done at expert operator on 15433.6
# Cust 975 is assigned to an expert operator at 15433.6
# Cust 976 is done at unskilled operator on 15437.8
# Cust 975 is done at expert operator on 15442.3
# Cust 976 is assigned to an expert operator at 15442.3
# Cust 977 initiated a call at 15444
# Cust 977 is assigned to an unskilled_operator at 15444
# duration is 3.7998885570760517
# Cust 978 initiated a call at 15447.3
# Cust 977 is done at unskilled operator on 15447.8
# Cust 978 is assigned to an unskilled_operator at 15447.8
# duration is 6.166661621217354
# Cust 979 initiated a call at 15450.6
# Cust 980 initiated a call at 15452
# Cust 981 initiated a call at 15452.2
# Cust 978 is done at unskilled operator on 15454
# Cust 979 is assigned to an unskilled_operator at 15454
# duration is 6.0589172757448715
# Cust 979 is done at unskilled operator on 15460.1
# Cust 980 is assigned to an unskilled_operator at 15460.1
# duration is 4.298060679797626
# Cust 976 is done at expert operator on 15461.6
# Cust 977 is assigned to an expert operator at 15461.6
# Cust 977 is done at expert operator on 15463
# Cust 978 is assigned to an expert operator at 15463
# Cust 980 is done at unskilled operator on 15464.4
# Cust 981 is assigned to an unskilled_operator at 15464.4
# duration is 5.18717604699996
# Cust 982 initiated a call at 15464.7
# Cust 981 is done at unskilled operator on 15469.6
# Cust 982 is assigned to an unskilled_operator at 15469.6
# duration is 3.508653321221532
# Cust 982 is done at unskilled operator on 15473.1
# Cust 978 is done at expert operator on 15474.4
# Cust 979 is assigned to an expert operator at 15474.4
# A break is initiated at 15477
# Cust 979 is done at expert operator on 15479
# Cust 980 is assigned to an expert operator at 15479
# Cust 983 initiated a call at 15487.1
# Cust 983 is assigned to an unskilled_operator at 15487.1
# duration is 4.891837910352794
# Cust 980 is done at expert operator on 15490.8
# Cust 981 is assigned to an expert operator at 15490.8
# Cust 983 is done at unskilled operator on 15491.9
# Cust 981 is done at expert operator on 15492.5
# Cust 982 is assigned to an expert operator at 15492.5
# Cust 982 is done at expert operator on 15496.8
# Cust 983 is assigned to an expert operator at 15496.8
# A break is initiated at 15497
# A break is initiated at 15520
# Cust 984 initiated a call at 15520.9
# Cust 984 is assigned to an unskilled_operator at 15520.9
# duration is 4.107806450428129
# Cust 985 initiated a call at 15523.8
# Cust 984 is done at unskilled operator on 15525
# Cust 985 is assigned to an unskilled_operator at 15525
# duration is 5.317080676711103
# Cust 985 is done at unskilled operator on 15530.3
# Cust 983 is done at expert operator on 15553.2
# Cust 984 is assigned to an expert operator at 15553.2
# Cust 984 is done at expert operator on 15560
# Cust 985 is assigned to an expert operator at 15560
# Cust 985 is done at expert operator on 15563.6
# A break is finished at 15568.6
# A break is finished at 15573.6
# A break is finished at 15578.6
# Cust 986 initiated a call at 15581.6
# Cust 986 is assigned to an unskilled_operator at 15581.6
# duration is 0.7099648827309455
# Cust 986 is done at unskilled operator on 15582.3
# Cust 986 is assigned to an expert operator at 15582.3
# Cust 986 is done at expert operator on 15591.1
# Cust 987 initiated a call at 15615.4
# Cust 987 is assigned to an unskilled_operator at 15615.4
# duration is 4.014045272941767
# Cust 988 initiated a call at 15618.7
# Cust 987 is done at unskilled operator on 15619.4
# Cust 987 is assigned to an expert operator at 15619.4
# Cust 988 is assigned to an unskilled_operator at 15619.4
# duration is 4.49465620045794
# Cust 988 is done at unskilled operator on 15623.9
# Cust 989 initiated a call at 15631.2
# Cust 989 is assigned to an unskilled_operator at 15631.2
# duration is 4.899129248580343
# Cust 987 is done at expert operator on 15634.7
# Cust 988 is assigned to an expert operator at 15634.7
# Cust 990 initiated a call at 15635.7
# Cust 989 is done at unskilled operator on 15636.1
# Cust 990 is assigned to an unskilled_operator at 15636.1
# duration is 2.7769176819607235
# Cust 990 is done at unskilled operator on 15638.8
# Cust 991 initiated a call at 15640
# Cust 991 is assigned to an unskilled_operator at 15640
# duration is 4.388842658008143
# Cust 991 is done at unskilled operator on 15644.4
# A break is initiated at 15649
# Cust 988 is done at expert operator on 15650.9
# Cust 989 is assigned to an expert operator at 15650.9
# A break is initiated at 15653
# Cust 989 is done at expert operator on 15655.8
# Cust 990 is assigned to an expert operator at 15655.8
# Cust 992 initiated a call at 15657.6
# Cust 992 is assigned to an unskilled_operator at 15657.6
# duration is 1.651718225881619
# Cust 992 is done at unskilled operator on 15659.2
# Cust 990 is done at expert operator on 15669
# Cust 991 is assigned to an expert operator at 15669
# Cust 991 is done at expert operator on 15670.8
# Cust 992 is assigned to an expert operator at 15670.8
# Cust 992 is done at expert operator on 15673.2
# A break is finished at 15678.2
# A break is finished at 15683.2
# Cust 993 initiated a call at 15687.2
# Cust 993 is assigned to an unskilled_operator at 15687.2
# duration is 4.1446511382683395
# Cust 993 is done at unskilled operator on 15691.3
# Cust 993 is assigned to an expert operator at 15691.3
# Cust 993 is done at expert operator on 15697.1
# Cust 994 initiated a call at 15714.3
# Cust 994 is assigned to an unskilled_operator at 15714.3
# duration is 3.6363615643958984
# Cust 994 is done at unskilled operator on 15717.9
# Cust 994 is assigned to an expert operator at 15717.9
# Cust 994 is done at expert operator on 15722.2
# Cust 995 initiated a call at 15745.1
# Cust 995 is assigned to an unskilled_operator at 15745.1
# duration is 2.831626833805558
# Cust 995 is done at unskilled operator on 15747.9
# Cust 995 is assigned to an expert operator at 15747.9
# Cust 996 initiated a call at 15753
# Cust 996 is assigned to an unskilled_operator at 15753
# duration is 3.8596450891363423
# Cust 996 is done at unskilled operator on 15756.8
# Cust 995 is done at expert operator on 15760.2
# Cust 996 is assigned to an expert operator at 15760.2
# Cust 996 is done at expert operator on 15771.4
# Cust 997 initiated a call at 15778.3
# Cust 997 is assigned to an unskilled_operator at 15778.3
# duration is 5.125421949731263
# Cust 997 is done at unskilled operator on 15783.4
# Cust 997 is assigned to an expert operator at 15783.4
# Cust 997 is done at expert operator on 15783.6
# Cust 998 initiated a call at 15784.2
# Cust 998 is assigned to an unskilled_operator at 15784.2
# duration is 4.319456646752153
# Cust 998 is done at unskilled operator on 15788.5
# Cust 998 is assigned to an expert operator at 15788.5
# Cust 999 initiated a call at 15791
# Cust 999 is assigned to an unskilled_operator at 15791
# duration is 5.910721943552908
# Cust 1000 initiated a call at 15795.4
# Cust 998 is done at expert operator on 15796.1
# Cust 999 is done at unskilled operator on 15796.9
# Cust 999 is assigned to an expert operator at 15796.9
# Cust 1000 is assigned to an unskilled_operator at 15796.9
# duration is 1.9410425967347757
# Cust 1000 is done at unskilled operator on 15798.9
# Cust 999 is done at expert operator on 15815.8
# Cust 1000 is assigned to an expert operator at 15815.8
# Cust 1000 is done at expert operator on 15818.9

# %% [markdown]
# ## Results

# %%
print("Server utilization for unskilled operator is %s" %(working_time_unskilled/total_time))
# Out:
# Server utilization for unskilled operator is 0.26711978842205913

# %%
print("Server utilization for expert operator is %s" %(working_time_expert/total_time))
# Out:
# Server utilization for expert operator is 0.6174926883712085

# %%
print("Average total waiting time for both operators is %s" %(total_waiting_time[0]/NUMBER_OF_CUSTOMERS))
# Out:
# Average total waiting time for both operators is 17.222193774780926

# %%
print("Maximum total waiting time to total system time ratio is %s" %(max_time))
# Out:
# Maximum total waiting time to total system time ratio is 0.9809653299888266

# %%
print("Average number of people waiting to be served by the expert operator is %s" %(total_waiting_time_expert[0]/total_time))
# Out:
# Average number of people waiting to be served by the expert operator is 1.0270952105307398
